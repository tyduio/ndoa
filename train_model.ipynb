# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import joblib

# %%
df = pd.read_csv("clean_marriage_data.csv")

df.head()
# Out:
#    duration  kujimwaga helping fam_id parent_supp   boy_finan  trust_level  \
# 0       8.4         50      no     no          no     student           10
# 1       1.3          6     yes    yes         yes     student            5
# 2       0.7         19      no     no         yes     student            1
# 3       5.2          0      no    yes         yes   own_money            3
# 4       4.3         24     yes     no         yes  parent_aid            6
#
#       HARUSI
# 0   HATUNAYO
# 1    TUNAYO
# 2  HATUNAYO
# 3    TUNAYO
# 4    TUNAYO

# %%
# check missing values
df.isnull().sum()
# Out:
# duration       0
# kujimwaga      0
# helping        0
# fam_id         0
# parent_supp    0
# boy_finan      0
# trust_level    0
# HARUSI         0
# dtype: int64

# %%
# drop missing values
df = df.dropna()

# remove duplicates
df = df.drop_duplicates()

df.shape
# Out:
# (100, 8)

# %%
le = LabelEncoder()

categorical_cols = ["helping", "fam_id", "parent_supp", "boy_finan", "HARUSI"]

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
#    duration  kujimwaga  helping  fam_id  parent_supp  boy_finan  trust_level  \
# 0       8.4         50        0       0            2          2           10
# 1       1.3          6        1       1            3          2            5
# 2       0.7         19        0       0            3          2            1
# 3       5.2          0        0       1            3          0            3
# 4       4.3         24        1       0            3          1            6
#
#    HARUSI
# 0       0
# 1       3
# 2       1
# 3       3
# 4       3

# %%
X = df.drop("HARUSI", axis=1)
y = df["HARUSI"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

print("Train size:", X_train.shape)
print("Test size:", X_test.shape)
# Out:
# Train size: (80, 7)
# Test size: (20, 7)

# %%
model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.55

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.42      0.83      0.56         6
#            3       0.75      0.46      0.57        13
#
#     accuracy                           0.55        20
#    macro avg       0.39      0.43      0.38        20
# weighted avg       0.61      0.55      0.54        20
# E:\Users\anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# E:\Users\anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# E:\Users\anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[0 0 1]
#  [0 5 1]
#  [0 7 6]]

# %%
joblib.dump(model, "marriage_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
# mfano wa input mpya
new_data = np.array([[5, 25, 1, 2, 1, 0, 7]])

# scale
new_data_scaled = scaler.transform(new_data)

# predict
prediction = model.predict(new_data_scaled)

print("Prediction:", prediction)
# Out:
# Prediction: [3]
# E:\Users\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
